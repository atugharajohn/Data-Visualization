# %% [markdown]
# # Python Code for Loading DataSet

# %%
import pandas as pd #import pandas library
df=pd.read_csv("/kaggle/input/adult-income-census/adult income1.csv") 
#load data to dataframe ‘df’
df.head() #Display top 5 rows of data

# %% [markdown]
# ## Output
# ![image2.png](attachment:image2.png)
